# %% [markdown]
# ass4
#
# April 2, 2023
#
# \[ \]: 1.
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>A <strong>for</strong> loop <strong>is</strong> generally used when
# you know the number of times you want to␣Here's an example of when to
# use a for loop:↪repeat a certain operation.</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > Example of using a **for** loop to print numbers **from** 1 to 5
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>for</strong> i <strong>in</strong> range(1, 6):<br />
# print(i)</p>
# <p>In this example, the <strong>for</strong> loop will execute five
# times, printing the numbers␣</p>
# <p>sequence of numbers <strong>from</strong> 1 to 5, which the
# <strong>for</strong> loop iterates over.↪<strong>from</strong> 1 to 5.
# The range(1, 6) function generates a<br />
# On the other hand, a <strong>while</strong> loop <strong>is</strong>
# generally used when you want to repeat a␣ ↪certain operation until a
# specific condition <strong>is</strong></p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>Example of using a <strong>while</strong> loop to calculate the sum
# of integers <strong>from</strong> 1 to 100 i = 1<br />
# sum = 0<br />
# <strong>while</strong> i &lt;= 100:<br />
# sum += i<br />
# i += 1<br />
# print(sum)</p>
# <p>In this example, the <strong>while</strong> loop will keep executing
# until the condition i &lt;=␣</p>
# </blockquote>
# <p>of integers <strong>from</strong> 1 to 100 <strong>and</strong>
# prints the result. Since we don't know in advance␣↪100 becomes
# <strong>False</strong>. The loop calculates the sum</p>
# <blockquote>
# <p>more appropriate to use a <strong>while</strong> loop
# <strong>in</strong> this case.↪how many times the loop will execute,
# it's</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# \[ \]: 2.
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>WHILE LOOP:</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>n=10</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# 1
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>i=1<br />
# sum=0<br />
# product =1<br />
# <strong>while</strong> i&lt;=10:<br />
# sum=sum+i<br />
# product=product*i<br />
# i=i+1<br />
# print(sum)<br />
# print(product)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>FOR LOOP:</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>sum=0<br />
# product=1<br />
# i=1<br />
# <strong>for</strong> i <strong>in</strong> range(1,11):<br />
# sum=sum+i<br />
# product=product*i<br />
# print(sum)<br />
# print(product)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# \[5\]: 3.
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>n=int(input("enter the no. of units :")) <strong>if</strong>
# n&lt;100:<br />
# r=n*4.5<br />
# <strong>if</strong> n&gt;100 <strong>and</strong> n&lt;=200:<br />
# r=100*4.5 + (n-100)*6<br />
# <strong>if</strong> n&gt;200 <strong>and</strong> n&lt;=300:<br />
# r=100*4.5 + (100)*6+ (n-200)*10<br />
# <strong>else</strong>:<br />
# r=100*4.5 + (100)*6+ (100)*10+(n-300)*20 print(r)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > enter the no. of units : 310
# > 2250.0
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>FOR LOOP:</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# \[ \]: 4.
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>l=[]<br />
# <strong>for</strong> i <strong>in</strong> range(101):<br />
# c=i**3<br />
# <strong>if</strong> c%<strong>4</strong>==0 or c%5==0:<br />
# l.append(i)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# 2
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>print(l)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>WHILE LOOP:</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>l=[]<br />
# n=1<br />
# <strong>while</strong> n&lt;=100:<br />
# c=n**3<br />
# <strong>if</strong> c%<strong>4</strong>==0 or c%5==0:<br />
# l.append(n)<br />
# n=n+1<br />
# print(l)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# \[4\]: 5.
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>count=0<br />
# l=['a','e','i','o','u','A','I','E','O','U'] s="I want to become a data
# scientist"<br />
# n=len(s)<br />
# k=len(l)<br />
# <strong>for</strong> i <strong>in</strong> range(n):<br />
# <strong>for</strong> j <strong>in</strong> range(k):<br />
# <strong>if</strong> s[i]==l[j]:<br />
# count=count+1<br />
# print(count)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# 12
# \[ \]:
#
# 3
